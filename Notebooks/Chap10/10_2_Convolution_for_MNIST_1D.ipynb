# %% [markdown]
# <a href="https://colab.research.google.com/github/MefiMefi/udlbook/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-xvw31d3e
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-xvw31d3e
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.5.20)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=4f78e621d18267dc8c11a428e6711b6467f1cd96758205eebe25fb5ea045b043
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5i2n56it/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding="valid"),
nn.ReLU(),
nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
nn.ReLU(),
nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
nn.ReLU(),
nn.Flatten(),
nn.Linear(60,10))

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.873744, train error 75.68,  val loss 1.887994, percent error 78.00
# Epoch     1, train loss 1.482398, train error 60.28,  val loss 1.495360, percent error 62.20
# Epoch     2, train loss 1.326058, train error 53.53,  val loss 1.342881, percent error 55.60
# Epoch     3, train loss 1.284161, train error 53.08,  val loss 1.297098, percent error 56.10
# Epoch     4, train loss 1.262551, train error 51.25,  val loss 1.283954, percent error 54.40
# Epoch     5, train loss 1.188497, train error 48.28,  val loss 1.191165, percent error 49.80
# Epoch     6, train loss 1.110050, train error 46.70,  val loss 1.137198, percent error 47.90
# Epoch     7, train loss 1.004916, train error 39.60,  val loss 1.030628, percent error 42.60
# Epoch     8, train loss 0.913517, train error 36.42,  val loss 0.934773, percent error 35.50
# Epoch     9, train loss 0.842330, train error 32.95,  val loss 0.869544, percent error 34.60
# Epoch    10, train loss 0.741351, train error 29.38,  val loss 0.774899, percent error 30.80
# Epoch    11, train loss 0.733970, train error 28.38,  val loss 0.770430, percent error 29.10
# Epoch    12, train loss 0.614303, train error 23.32,  val loss 0.676184, percent error 27.40
# Epoch    13, train loss 0.520299, train error 19.40,  val loss 0.586233, percent error 22.30
# Epoch    14, train loss 0.456095, train error 16.43,  val loss 0.516189, percent error 18.70
# Epoch    15, train loss 0.422698, train error 15.15,  val loss 0.496537, percent error 18.60
# Epoch    16, train loss 0.346924, train error 11.45,  val loss 0.432071, percent error 14.60
# Epoch    17, train loss 0.347342, train error 12.15,  val loss 0.446271, percent error 14.90
# Epoch    18, train loss 0.313575, train error 11.07,  val loss 0.436248, percent error 14.40
# Epoch    19, train loss 0.278071, train error 9.50,  val loss 0.370751, percent error 13.60
# Epoch    20, train loss 0.219469, train error 7.53,  val loss 0.334796, percent error 11.10
# Epoch    21, train loss 0.194353, train error 6.45,  val loss 0.307702, percent error 11.30
# Epoch    22, train loss 0.237581, train error 8.80,  val loss 0.370609, percent error 14.20
# Epoch    23, train loss 0.223306, train error 7.93,  val loss 0.333366, percent error 11.90
# Epoch    24, train loss 0.228772, train error 7.95,  val loss 0.370415, percent error 12.70
# Epoch    25, train loss 0.155537, train error 4.78,  val loss 0.289989, percent error 9.70
# Epoch    26, train loss 0.172069, train error 5.68,  val loss 0.314246, percent error 11.30
# Epoch    27, train loss 0.200624, train error 6.97,  val loss 0.356869, percent error 11.40
# Epoch    28, train loss 0.161396, train error 5.62,  val loss 0.317908, percent error 10.00
# Epoch    29, train loss 0.144712, train error 4.85,  val loss 0.305500, percent error 10.70
# Epoch    30, train loss 0.142512, train error 4.88,  val loss 0.305515, percent error 9.90
# Epoch    31, train loss 0.131464, train error 4.32,  val loss 0.289552, percent error 9.90
# Epoch    32, train loss 0.137186, train error 4.45,  val loss 0.306838, percent error 9.50
# Epoch    33, train loss 0.108855, train error 3.38,  val loss 0.284562, percent error 9.90
# Epoch    34, train loss 0.127944, train error 3.90,  val loss 0.301960, percent error 10.20
# Epoch    35, train loss 0.106584, train error 3.12,  val loss 0.280720, percent error 8.80
# Epoch    36, train loss 0.114152, train error 3.45,  val loss 0.309729, percent error 10.30
# Epoch    37, train loss 0.099279, train error 3.05,  val loss 0.281996, percent error 8.70
# Epoch    38, train loss 0.103642, train error 3.22,  val loss 0.286029, percent error 9.80
# Epoch    39, train loss 0.127419, train error 4.18,  val loss 0.346891, percent error 10.50
# Epoch    40, train loss 0.083755, train error 2.30,  val loss 0.287128, percent error 8.20
# Epoch    41, train loss 0.079417, train error 2.12,  val loss 0.296405, percent error 8.70
# Epoch    42, train loss 0.074248, train error 1.88,  val loss 0.285676, percent error 8.60
# Epoch    43, train loss 0.074161, train error 2.05,  val loss 0.287988, percent error 9.10
# Epoch    44, train loss 0.068931, train error 1.75,  val loss 0.284791, percent error 8.80
# Epoch    45, train loss 0.074885, train error 2.40,  val loss 0.298200, percent error 9.30
# Epoch    46, train loss 0.067267, train error 1.70,  val loss 0.284012, percent error 8.90
# Epoch    47, train loss 0.065512, train error 1.62,  val loss 0.286126, percent error 8.90
# Epoch    48, train loss 0.069780, train error 1.82,  val loss 0.304093, percent error 9.00
# Epoch    49, train loss 0.069905, train error 2.03,  val loss 0.286777, percent error 8.50
# Epoch    50, train loss 0.071278, train error 2.12,  val loss 0.298895, percent error 9.10
# Epoch    51, train loss 0.066935, train error 1.75,  val loss 0.303729, percent error 8.60
# Epoch    52, train loss 0.065944, train error 1.68,  val loss 0.309388, percent error 8.80
# Epoch    53, train loss 0.059952, train error 1.62,  val loss 0.300913, percent error 8.80
# Epoch    54, train loss 0.057438, train error 1.40,  val loss 0.294243, percent error 9.20
# Epoch    55, train loss 0.062487, train error 1.62,  val loss 0.297243, percent error 9.40
# Epoch    56, train loss 0.058506, train error 1.55,  val loss 0.303474, percent error 9.40
# Epoch    57, train loss 0.055929, train error 1.53,  val loss 0.303916, percent error 8.50
# Epoch    58, train loss 0.052763, train error 1.28,  val loss 0.304492, percent error 8.70
# Epoch    59, train loss 0.048979, train error 1.10,  val loss 0.294662, percent error 8.70
# Epoch    60, train loss 0.046955, train error 0.82,  val loss 0.296281, percent error 8.50
# Epoch    61, train loss 0.045644, train error 0.90,  val loss 0.302873, percent error 8.80
# Epoch    62, train loss 0.045775, train error 0.97,  val loss 0.310502, percent error 9.00
# Epoch    63, train loss 0.044714, train error 0.93,  val loss 0.301492, percent error 9.00
# Epoch    64, train loss 0.044821, train error 0.85,  val loss 0.305137, percent error 9.10
# Epoch    65, train loss 0.043181, train error 0.82,  val loss 0.307242, percent error 8.70
# Epoch    66, train loss 0.042714, train error 0.80,  val loss 0.303823, percent error 8.90
# Epoch    67, train loss 0.042469, train error 0.70,  val loss 0.306106, percent error 8.90
# Epoch    68, train loss 0.041760, train error 0.78,  val loss 0.310928, percent error 8.90
# Epoch    69, train loss 0.041163, train error 0.75,  val loss 0.312643, percent error 8.90
# Epoch    70, train loss 0.042713, train error 1.00,  val loss 0.315152, percent error 8.50
# Epoch    71, train loss 0.041260, train error 0.95,  val loss 0.315364, percent error 8.80
# Epoch    72, train loss 0.040186, train error 0.80,  val loss 0.313585, percent error 8.90
# Epoch    73, train loss 0.039584, train error 0.70,  val loss 0.314107, percent error 8.90
# Epoch    74, train loss 0.040282, train error 0.80,  val loss 0.318996, percent error 9.20
# Epoch    75, train loss 0.038805, train error 0.62,  val loss 0.314869, percent error 8.80
# Epoch    76, train loss 0.038316, train error 0.65,  val loss 0.314066, percent error 9.00
# Epoch    77, train loss 0.037911, train error 0.62,  val loss 0.316598, percent error 9.00
# Epoch    78, train loss 0.037466, train error 0.75,  val loss 0.320510, percent error 9.00
# Epoch    79, train loss 0.037678, train error 0.60,  val loss 0.319339, percent error 9.20
# Epoch    80, train loss 0.036100, train error 0.57,  val loss 0.322083, percent error 9.00
# Epoch    81, train loss 0.036029, train error 0.50,  val loss 0.323454, percent error 8.90
# Epoch    82, train loss 0.035256, train error 0.53,  val loss 0.322045, percent error 9.00
# Epoch    83, train loss 0.035150, train error 0.50,  val loss 0.325911, percent error 9.00
# Epoch    84, train loss 0.035477, train error 0.65,  val loss 0.327281, percent error 9.00
# Epoch    85, train loss 0.034565, train error 0.50,  val loss 0.324559, percent error 9.00
# Epoch    86, train loss 0.034270, train error 0.57,  val loss 0.325734, percent error 9.10
# Epoch    87, train loss 0.034157, train error 0.53,  val loss 0.326992, percent error 8.90
# Epoch    88, train loss 0.033889, train error 0.62,  val loss 0.328144, percent error 9.00
# Epoch    89, train loss 0.033859, train error 0.53,  val loss 0.326447, percent error 9.10
# Epoch    90, train loss 0.033753, train error 0.47,  val loss 0.330574, percent error 9.10
# Epoch    91, train loss 0.033606, train error 0.57,  val loss 0.330362, percent error 8.80
# Epoch    92, train loss 0.033336, train error 0.50,  val loss 0.329216, percent error 8.90
# Epoch    93, train loss 0.033402, train error 0.45,  val loss 0.328096, percent error 9.00
# Epoch    94, train loss 0.033280, train error 0.53,  val loss 0.332187, percent error 8.80
# Epoch    95, train loss 0.032645, train error 0.47,  val loss 0.330887, percent error 9.00
# Epoch    96, train loss 0.036721, train error 0.82,  val loss 0.341889, percent error 9.00
# Epoch    97, train loss 0.032604, train error 0.57,  val loss 0.333496, percent error 8.90
# Epoch    98, train loss 0.032082, train error 0.47,  val loss 0.333169, percent error 9.00
# Epoch    99, train loss 0.031727, train error 0.43,  val loss 0.333113, percent error 8.90
