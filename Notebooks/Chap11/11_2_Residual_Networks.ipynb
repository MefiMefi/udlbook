# %% [markdown]
# <a href="https://colab.research.google.com/github/MefiMefi/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-u8zzvtdu
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-u8zzvtdu
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.5.20)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=39b8e93daad530bb4241c756c069d5a8ac19f161f9403c3b6678f229b821931e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-b7akom1f/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    # linear1 first
    h = self.linear1(x)

    # First residual block: ReLU + linear2 + residual connection
    # Store 'h' before ReLU and linear2 for the skip connection
    identity1 = h
    h = h.relu()
    h = self.linear2(h)
    h = h + identity1

    # Second residual block: ReLU + linear3 + residual connection
    # Store 'h' after the first block but before ReLU and linear3 for the skip connection
    identity2 = h
    h = h.relu()
    h = self.linear3(h)
    h = h + identity2

    # linear4 at end
    return self.linear4(h)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.720857, train error 63.00,  val loss 1.854293, percent error 67.20
# Epoch     1, train loss 1.161265, train error 43.47,  val loss 1.301098, percent error 49.50
# Epoch     2, train loss 0.975949, train error 37.25,  val loss 1.223154, percent error 47.70
# Epoch     3, train loss 0.859550, train error 33.38,  val loss 1.145054, percent error 44.50
# Epoch     4, train loss 0.817280, train error 31.70,  val loss 1.186934, percent error 43.90
# Epoch     5, train loss 0.719971, train error 26.70,  val loss 1.206868, percent error 43.70
# Epoch     6, train loss 0.658058, train error 25.07,  val loss 1.144619, percent error 43.90
# Epoch     7, train loss 0.563955, train error 20.93,  val loss 1.118473, percent error 41.10
# Epoch     8, train loss 0.575483, train error 22.38,  val loss 1.188466, percent error 38.80
# Epoch     9, train loss 0.564205, train error 20.32,  val loss 1.322649, percent error 43.10
# Epoch    10, train loss 0.498529, train error 19.70,  val loss 1.221627, percent error 38.10
# Epoch    11, train loss 0.555269, train error 20.75,  val loss 1.371234, percent error 39.40
# Epoch    12, train loss 0.482254, train error 18.35,  val loss 1.264255, percent error 38.50
# Epoch    13, train loss 0.396121, train error 14.90,  val loss 1.297964, percent error 38.10
# Epoch    14, train loss 0.393820, train error 13.97,  val loss 1.354125, percent error 37.30
# Epoch    15, train loss 0.348792, train error 13.18,  val loss 1.406244, percent error 37.60
# Epoch    16, train loss 0.325810, train error 12.40,  val loss 1.411514, percent error 36.60
# Epoch    17, train loss 0.383042, train error 13.28,  val loss 1.639070, percent error 37.70
# Epoch    18, train loss 0.321975, train error 11.12,  val loss 1.459752, percent error 34.90
# Epoch    19, train loss 0.391496, train error 13.65,  val loss 1.529139, percent error 37.80
# Epoch    20, train loss 0.109005, train error 3.18,  val loss 1.257879, percent error 34.10
# Epoch    21, train loss 0.053456, train error 0.78,  val loss 1.221999, percent error 30.40
# Epoch    22, train loss 0.033067, train error 0.25,  val loss 1.266160, percent error 31.40
# Epoch    23, train loss 0.024047, train error 0.10,  val loss 1.308448, percent error 30.80
# Epoch    24, train loss 0.018176, train error 0.03,  val loss 1.347504, percent error 30.30
# Epoch    25, train loss 0.014467, train error 0.03,  val loss 1.405419, percent error 30.80
# Epoch    26, train loss 0.012376, train error 0.00,  val loss 1.439335, percent error 31.20
# Epoch    27, train loss 0.010408, train error 0.00,  val loss 1.464823, percent error 30.60
# Epoch    28, train loss 0.009192, train error 0.00,  val loss 1.496647, percent error 31.10
# Epoch    29, train loss 0.008196, train error 0.00,  val loss 1.521285, percent error 31.10
# Epoch    30, train loss 0.007504, train error 0.00,  val loss 1.545487, percent error 30.70
# Epoch    31, train loss 0.006761, train error 0.00,  val loss 1.561915, percent error 31.00
# Epoch    32, train loss 0.006260, train error 0.00,  val loss 1.583899, percent error 31.00
# Epoch    33, train loss 0.005768, train error 0.00,  val loss 1.600910, percent error 30.90
# Epoch    34, train loss 0.005347, train error 0.00,  val loss 1.617082, percent error 30.80
# Epoch    35, train loss 0.004992, train error 0.00,  val loss 1.635286, percent error 30.90
# Epoch    36, train loss 0.004683, train error 0.00,  val loss 1.648638, percent error 31.10
# Epoch    37, train loss 0.004403, train error 0.00,  val loss 1.662320, percent error 30.80
# Epoch    38, train loss 0.004163, train error 0.00,  val loss 1.678239, percent error 31.20
# Epoch    39, train loss 0.003933, train error 0.00,  val loss 1.688453, percent error 31.10
# Epoch    40, train loss 0.003826, train error 0.00,  val loss 1.695862, percent error 31.20
# Epoch    41, train loss 0.003731, train error 0.00,  val loss 1.701018, percent error 31.10
# Epoch    42, train loss 0.003637, train error 0.00,  val loss 1.707412, percent error 31.10
# Epoch    43, train loss 0.003550, train error 0.00,  val loss 1.712866, percent error 31.00
# Epoch    44, train loss 0.003468, train error 0.00,  val loss 1.720204, percent error 31.30
# Epoch    45, train loss 0.003387, train error 0.00,  val loss 1.724026, percent error 31.30
# Epoch    46, train loss 0.003312, train error 0.00,  val loss 1.729867, percent error 31.30
# Epoch    47, train loss 0.003238, train error 0.00,  val loss 1.734674, percent error 31.30
# Epoch    48, train loss 0.003169, train error 0.00,  val loss 1.740763, percent error 31.30
# Epoch    49, train loss 0.003103, train error 0.00,  val loss 1.745743, percent error 31.30
# Epoch    50, train loss 0.003037, train error 0.00,  val loss 1.750772, percent error 31.50
# Epoch    51, train loss 0.002975, train error 0.00,  val loss 1.754521, percent error 31.50
# Epoch    52, train loss 0.002915, train error 0.00,  val loss 1.760047, percent error 31.40
# Epoch    53, train loss 0.002859, train error 0.00,  val loss 1.764133, percent error 31.50
# Epoch    54, train loss 0.002803, train error 0.00,  val loss 1.769589, percent error 31.60
# Epoch    55, train loss 0.002749, train error 0.00,  val loss 1.773819, percent error 31.50
# Epoch    56, train loss 0.002698, train error 0.00,  val loss 1.778632, percent error 31.50
# Epoch    57, train loss 0.002648, train error 0.00,  val loss 1.782606, percent error 31.50
# Epoch    58, train loss 0.002599, train error 0.00,  val loss 1.788154, percent error 31.50
# Epoch    59, train loss 0.002553, train error 0.00,  val loss 1.792211, percent error 31.50
# Epoch    60, train loss 0.002529, train error 0.00,  val loss 1.794232, percent error 31.50
# Epoch    61, train loss 0.002507, train error 0.00,  val loss 1.796439, percent error 31.50
# Epoch    62, train loss 0.002485, train error 0.00,  val loss 1.798187, percent error 31.50
# Epoch    63, train loss 0.002464, train error 0.00,  val loss 1.800315, percent error 31.50
# Epoch    64, train loss 0.002443, train error 0.00,  val loss 1.802221, percent error 31.50
# Epoch    65, train loss 0.002422, train error 0.00,  val loss 1.804261, percent error 31.50
# Epoch    66, train loss 0.002402, train error 0.00,  val loss 1.806611, percent error 31.50
# Epoch    67, train loss 0.002382, train error 0.00,  val loss 1.808515, percent error 31.50
# Epoch    68, train loss 0.002362, train error 0.00,  val loss 1.810428, percent error 31.50
# Epoch    69, train loss 0.002342, train error 0.00,  val loss 1.812442, percent error 31.50
# Epoch    70, train loss 0.002323, train error 0.00,  val loss 1.814201, percent error 31.50
# Epoch    71, train loss 0.002304, train error 0.00,  val loss 1.816597, percent error 31.50
# Epoch    72, train loss 0.002286, train error 0.00,  val loss 1.818106, percent error 31.50
# Epoch    73, train loss 0.002267, train error 0.00,  val loss 1.820006, percent error 31.50
# Epoch    74, train loss 0.002249, train error 0.00,  val loss 1.821751, percent error 31.50
# Epoch    75, train loss 0.002231, train error 0.00,  val loss 1.824288, percent error 31.50
# Epoch    76, train loss 0.002214, train error 0.00,  val loss 1.825441, percent error 31.50
# Epoch    77, train loss 0.002196, train error 0.00,  val loss 1.827629, percent error 31.50
# Epoch    78, train loss 0.002180, train error 0.00,  val loss 1.829160, percent error 31.50
# Epoch    79, train loss 0.002163, train error 0.00,  val loss 1.831524, percent error 31.50
# Epoch    80, train loss 0.002154, train error 0.00,  val loss 1.832134, percent error 31.50
# Epoch    81, train loss 0.002146, train error 0.00,  val loss 1.832943, percent error 31.50
# Epoch    82, train loss 0.002138, train error 0.00,  val loss 1.833980, percent error 31.50
# Epoch    83, train loss 0.002130, train error 0.00,  val loss 1.834565, percent error 31.50
# Epoch    84, train loss 0.002122, train error 0.00,  val loss 1.835562, percent error 31.50
# Epoch    85, train loss 0.002113, train error 0.00,  val loss 1.836658, percent error 31.50
# Epoch    86, train loss 0.002106, train error 0.00,  val loss 1.837603, percent error 31.50
# Epoch    87, train loss 0.002098, train error 0.00,  val loss 1.838387, percent error 31.50
# Epoch    88, train loss 0.002090, train error 0.00,  val loss 1.839228, percent error 31.50
# Epoch    89, train loss 0.002082, train error 0.00,  val loss 1.840029, percent error 31.50
# Epoch    90, train loss 0.002074, train error 0.00,  val loss 1.840901, percent error 31.50
# Epoch    91, train loss 0.002067, train error 0.00,  val loss 1.841779, percent error 31.50
# Epoch    92, train loss 0.002059, train error 0.00,  val loss 1.842538, percent error 31.50
# Epoch    93, train loss 0.002051, train error 0.00,  val loss 1.843562, percent error 31.50
# Epoch    94, train loss 0.002044, train error 0.00,  val loss 1.844297, percent error 31.50
# Epoch    95, train loss 0.002037, train error 0.00,  val loss 1.845135, percent error 31.50
# Epoch    96, train loss 0.002029, train error 0.00,  val loss 1.846070, percent error 31.50
# Epoch    97, train loss 0.002021, train error 0.00,  val loss 1.847048, percent error 31.50
# Epoch    98, train loss 0.002014, train error 0.00,  val loss 1.847625, percent error 31.50
# Epoch    99, train loss 0.002007, train error 0.00,  val loss 1.848640, percent error 31.50

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
